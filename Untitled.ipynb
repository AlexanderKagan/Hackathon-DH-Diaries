# %%
import numpy as np
import pandas as pd

# %%
from collections import Counter
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from os import listdir
from sklearn.metrics.pairwise import cosine_similarity
import pymorphy2
morph = pymorphy2.MorphAnalyzer()

# %%
import gensim

# %%
razg_multi_seed = ['просто', 'авось', 'небось', \
                'таки', 'вовсе', 'раз',\
                'коли', 'уж', 'кстати', \
                'положим', 'ведь', 'впрочем', 'ну',
                'чуть', 'чтоб', 'ан', 'пускай', \
                'вдобавок', 'покамест', 'вдобавок']
off_multi_seed = ['соответственно', 'следовательно', 'сущность', \
                'итак', 'безусловно', 'исходя', \
                'вероятно', 'дабы', 'поскольку', 'постольку', \
                'посему', 'некий', 'таковой', 'напротив', \
                'точнее', 'причем', 'притом', \
                'следовательно', 'собственно', 'нежели']

# %%
fasttext_model = gensim.models.KeyedVectors.load("fasttext/model.model")

# %%
def embed_list(lst:list, model:object):
    arr = np.array([model.get_vector(n) for n in lst])
    return np.average(arr, axis=0)

# %%
def cos_sim(avg_vec:object, axis:object):
    return cosine_similarity(avg_vec, axis)

# %%
all_words = list()
for n in new["notes\n"]:
    all_words.append(re.findall(r"[а-яА-ЯёЁ]+", n))

# %%
len(all_words)
# Out:
# 72423

# %%
razg = embed_list(razg_multi_seed, fasttext_model)
off = embed_list(off_multi_seed, fasttext_model)

# %%
axis = razg - off

# %%
sims = []
for i, n in enumerate(all_words):
    sims.append(cos_sim(np.atleast_2d(embed_list(n, fasttext_model)), np.atleast_2d(axis)))

# %%
sims[0][0][0]
# Out:
# 0.013356676

# %%
new['sims'] = [n[0][0] for n in sims]

# %%
new['class'] = np.zeros([72423])

# %%
classes = []
sm = new['sims']
for i in range(72423):
    if sm.iloc[i] > 0.2:
        classes.append(4)
    elif sm.iloc[i] >= 0:
        classes.append(3)
    elif sm.iloc[i] < -0.2:
        classes.append(0)
    elif sm.iloc[i] < 0:
        classes.append(1)

# %%
new['class'] = classes

# %%
new.loc[new['sims'] > 0.06]
# Out:
#                                                     notes  \
# 78224   Среда. Мороз не сдает и держится между 15 и 20...
# 78225   Был опять у своей вечерни; я бы не мог теперь ...
# 78227   1) «Театр», Москва, № 126, 1907 г., декабрь.  ...
# 78228   Четверг. Рождество близко, но кажется, что впе...
# 78229   Четверг. О. Смирнову в Лондон ответил.    \nЯв...
# ...                                                   ...
# 150638  Вернувся з Харкова Лозієв. Каже — бачив Озерсь...
# 150639  В субботу. Встреча тридцать девятая    \nПодар...
# 150640  **Суббота**. Сегодня рано утром я еду в Бийск,...
# 150641  31, суббота.  В бюро С[екции] н[аучных] р[абот...
# 150644  Суббота.    \nСегодня на работу не пошел — зар...
#
#                                                   notes\n       dates    id  \
# 78224   среда. мороз не сдавать и держаться между  и ....    1908/1/1   182
# 78225   быть опять у свой вечерня я бы не мочь теперь ...    1908/1/1   157
# ...

# %%
new.to_csv('example.csv', sep='\t', encoding='utf-8')

# %%
from sklearn.feature_extraction.text import TfidfTransformer, TfidfVectorizer

# %%
from sklearn.linear_model import LogisticRegression
import eli5
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
tfidf = TfidfVectorizer()

# %%
X = tfidf.fit_transform(new['notes\n'])
y = new['class']

# %%
logreg = LogisticRegression()

# %%
logreg.fit(X, y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
eli5.show_weights(logreg, top=50, feature_names=tfidf.get_feature_names())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=0
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=1
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=3
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
# ...

# %%
dataset = pd.read_csv('whole_table_with_lemm.csv', sep='\t', index_col=0, encoding='UTF-8')

# %%
this = str(dataset.iloc[384518,1])

# %%
dataset["notes\n"] = [re.sub(r'[^а-яА-ЯёЁ. ]', "", sent) for sent in dataset["notes\n"]]

# %%
dataset["notes\n"].tail(10)
# Out:
# 384516    .    иногда я казаться что мы весь мой возраст...
# 384517    только что посмотреть еще раз художественный ф...
# 384518    лишний человек  век чацкий евгений онегин пече...
# 384519        в свой поиск смысл жизнь который начинатьс...
# 384520    человек не мочь сам судить себя. пусть я судит...
# 384521    весь мой личный жизнь являться чудо божий весь...
# 384522    мочь быть то место где я сейчас находиться где...
# 384523    если взглядывать на мой жизнь проживать год то...
# 384524    весь мой жизнь после уход из отеческий дом в  ...
# 384525
# Name: notes\n, dtype: object

# %%
dataset['dates'].loc[lambda item: item > '1900/01/01'].loc[lambda item: item < '1950/01/01']
# Out:
# 56784       1900/1/1
# 56785       1900/1/1
# 56786       1900/1/1
# 56787       1900/1/1
# 56788       1900/1/1
#              ...
# 261690    1949/12/30
# 261691    1949/12/31
# 261692    1949/12/31
# 261693    1949/12/31
# 261694    1949/12/31
# Name: dates, Length: 204911, dtype: object

# %%
new = dataset.loc[dataset['dates'] > '1908/01/01'].loc[dataset['dates'] < '1928/01/01']

# %%
new.to_csv('new.csv', sep='\t')

# %%
dataset['dates'].loc[lambda item: item > '2000/01/01']
# Out:
# 372267     2000/1/1
# 372268     2000/1/1
# 372269     2000/1/1
# 372270     2000/1/1
# 372271     2000/1/2
#             ...
# 384521     2018/6/3
# 384522    2018/6/12
# 384523    2018/6/13
# 384524    2018/6/17
# 384525     2959/3/9
# Name: dates, Length: 12259, dtype: object

# %%
dataset.iloc[400,1]
# Out:
# '  .                             .             .                              .                             .            .                 .               .               .                                .    .    .'

# %%
new.head(5)
# Out:
#                                                    notes  \
# 78222  В Петербурге идут усиленные грабежи; что ни де...
# 78223  Среда. Японский Новый год    \nС 8 часов Литур...
# 78224  Среда. Мороз не сдает и держится между 15 и 20...
# 78225  Был опять у своей вечерни; я бы не мог теперь ...
# 78226  *19* *Дек*.    \nИсключительныхъ привязанносте...
#
#                                                  notes\n     dates   id  \
# 78222  в петербург идти усилять грабеж что ни день то...  1908/1/1  543
# 78223  среда. японский новый год    с  часы литургия....  1908/1/1  577
# 78224  среда. мороз не сдавать и держаться между  и ....  1908/1/1  182
# 78225  быть опять у свой вечерня я бы не мочь теперь ...  1908/1/1  157
# 78226   дека.    исключительный привязанность не мочь...  1908/1/1  196
#
#                                   author
# 78222         Сергей Рудольфович Минцлов
# 78223                  Николай  Японский
# 78224  Константин Константинович Романов
# ...

# %%
new['notes\n'].iloc[2]
# Out:
# 'среда. мороз не сдавать и держаться между  и . я мучить нарыв на живот на волосистый его часть.  у татиана простуда и она не выходить из свой комната.    быть у преображенец на ташкентский обед. впервые собираться мы старый преображенец в полк после происходить в немой лето  год прискорбный событие. съезжаться много начинать с бывший и теперешний главнокомандующий и кончать младший чин. недостаточный число офицер вызывать прикомандирование к полк оберофицер от капитан до поручик из армия. теперь в полк три разряд офицер коренной служить еще под мой начальство поступать после я и я почти незнакомый и наконец молодежь известный я в качество мой питомец. из второй и третий разряд многие как говориться не приходиться ко двор и не сходиться с коренной.  приятно проводить время среди свой сослуживец и питомец. '
